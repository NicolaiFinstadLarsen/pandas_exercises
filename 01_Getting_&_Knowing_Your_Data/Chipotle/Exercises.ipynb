# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
chipo["order_id"].count().sum()
# Out:
# np.int64(4622)

# %%
chipo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   str
#  3   choice_description  3376 non-null   str
#  4   item_price          4622 non-null   str
# dtypes: int64(2), str(3)
# memory usage: 180.7 KB

# %%
# Solution 2
chipo.shape
# Out:
# (4622, 5)

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='str')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
# Viser med antall
# best_item = chipo[["item_name", "quantity"]].groupby("item_name").sum().sort_values("quantity", ascending=False).head(1) 

# Uten antall som dataframe, huske å resette index da groupby gjør item_name til index
# best_item = chipo[["item_name", "quantity"]].groupby("item_name").sum().sort_values("quantity", ascending=False).head(1).reset_index()
# best_item[["item_name"]]

# Bruke index og første row for å hente ut item_name som string
best_item = chipo[["item_name", "quantity"]].groupby("item_name").sum().sort_values("quantity", ascending=False).head(1)
best_item.index[0]
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
best_item[["quantity"]]
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
chipo.groupby("choice_description")["quantity"].sum().idxmax()

# resette dataframe
total_orders = chipo

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo[["quantity"]].sum()
# Out:
# quantity    4972
# dtype: int64

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo.dtypes["item_price"]
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
chipo["item_price"] = chipo["item_price"].str.replace("$", "").astype(float)

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   str
#  3   choice_description  3376 non-null   str
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 180.7 KB

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo["revenue"] = chipo["quantity"] * chipo["item_price"]
total = chipo["revenue"].sum()
print(f"Total revenue was ${total:,.2f}".replace(",", " "))
# Out:
# Total revenue was $39 237.02

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
chipo["order_id"].value_counts().count()
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  revenue
# 0                                                   NaN        2.39     2.39
# ...

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
chipo[["order_id", "revenue"]] \
    .groupby("order_id")["revenue"].sum().mean()
# Out:
# np.float64(21.39423118865867)

# %%
ordered_group = chipo.groupby("order_id")["revenue"].sum()
ordered_group.mean()
# Out:
# np.float64(21.39423118865867)

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
chipo["item_name"].nunique() #Better
# chipo.item_name.value_counts().count()
# Out:
# np.int64(50)
